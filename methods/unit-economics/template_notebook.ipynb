# %% [markdown]
# # Unit Economics — template
#
# Инструкция: загрузите CSV с колонками: date, channel, impressions, clicks, installs, purchases, revenue, cost.
# Ноутбук выполняет агрегацию по каналу и рассчитывает CAC, AOV, ROAS и даёт простую рекомендацию.
